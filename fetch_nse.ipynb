# %%
import requests
import pandas as pd
from pandas import json_normalize # life saver

# %%
headers = {
    'Connection': 'keep-alive',
    'Cache-Control': 'max-age=0',
    'DNT': '1',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.79 Safari/537.36',
    'Sec-Fetch-User': '?1',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Sec-Fetch-Site': 'none',
    'Sec-Fetch-Mode': 'navigate',
    'Accept-Encoding': 'gzip, deflate, br',
    'Accept-Language': 'en-US,en;q=0.9,hi;q=0.8',
    "Referer": "https://www.nseindia.com/market-data/live-equity-market",
}

# %%
def fetch_nse(url, headers):
    try:
        json_data = requests.get(url ,headers=headers).json()
    except ValueError:
        s =requests.Session()
        json_data = s.get("http://nseindia.com",headers=headers)
        json_data = s.get(url ,headers=headers).json()
    return json_data

# %%
url = r"https://www.nseindia.com/api/liveEquity-derivatives?index=nse50_opt"

# %%
json_data = fetch_nse(url=url, headers=headers)

# %%
lup = json_data['timestamp']
print("Last Updated Time: {}".format(lup))
# Out:
# Last Updated Time: 06-May-2022 15:30:00

# %%
df = json_normalize(json_data['data'], max_level=0)

# %%
# df.to_csv("nifty_50_opt.csv", header=True, index=False)

# %%
df
# Out:
#      underlying                       identifier instrumentType  \
# 0         NIFTY  OPTIDXNIFTY12-05-2022PE16400.00         OPTIDX
# 1         NIFTY  OPTIDXNIFTY12-05-2022CE16500.00         OPTIDX
# 2         NIFTY  OPTIDXNIFTY12-05-2022CE16400.00         OPTIDX
# 3         NIFTY  OPTIDXNIFTY12-05-2022CE17000.00         OPTIDX
# 4         NIFTY  OPTIDXNIFTY12-05-2022PE16000.00         OPTIDX
# ...         ...                              ...            ...
# 1753      NIFTY  OPTIDXNIFTY24-12-2025CE16000.00         OPTIDX
# 1754      NIFTY  OPTIDXNIFTY07-07-2022CE17050.00         OPTIDX
# 1755      NIFTY  OPTIDXNIFTY27-06-2024PE20000.00         OPTIDX
# 1756      NIFTY  OPTIDXNIFTY28-07-2022CE17250.00         OPTIDX
# 1757      NIFTY  OPTIDXNIFTY02-06-2022PE16650.00         OPTIDX
#
#          instrument           contract   expiryDate optionType  strikePrice  \
# 0     Index Options  NIFTY 12-May-2022  12-May-2022        Put        16400
# 1     Index Options  NIFTY 12-May-2022  12-May-2022       Call        16500
# 2     Index Options  NIFTY 12-May-2022  12-May-2022       Call        16400
# 3     Index Options  NIFTY 12-May-2022  12-May-2022       Call        17000
# 4     Index Options  NIFTY 12-May-2022  12-May-2022        Put        16000
# ...             ...                ...          ...        ...          ...
# 1753  Index Options  NIFTY 24-Dec-2025  24-Dec-2025       Call        16000
# 1754  Index Options  NIFTY 07-Jul-2022  07-Jul-2022       Call        17050
# 1755  Index Options  NIFTY 27-Jun-2024  27-Jun-2024        Put        20000
# 1756  Index Options  NIFTY 28-Jul-2022  28-Jul-2022       Call        17250
# 1757  Index Options  NIFTY 02-Jun-2022  02-Jun-2022        Put        16650
#
#       lastPrice  change  pChange    volume  totalTurnover         value  \
# 0        150.60   68.90    84.33  94188250   1.750960e+10  1.750960e+10
# 1        138.00 -153.95   -52.73  80734050   1.144082e+10  1.144082e+10
# 2        190.00 -167.45   -46.85  76019700   1.444298e+10  1.444298e+10
# 3         13.95  -40.65   -74.45  72002400   1.293163e+09  1.293163e+09
# 4         48.00   24.40   103.39  66223000   4.294562e+09  4.294562e+09
# ...         ...     ...      ...       ...            ...           ...
# 1753    4394.50    0.00     0.00         0   0.000000e+00  0.000000e+00
# 1754       0.00    0.00     0.00         0   0.000000e+00  0.000000e+00
# 1755       0.00    0.00     0.00         0   0.000000e+00  0.000000e+00
# 1756     400.00    0.00     0.00         0   0.000000e+00  0.000000e+00
# 1757       0.00    0.00     0.00         0   0.000000e+00  0.000000e+00
#
#       premiumTurnOver  underlyingValue  openInterest  noOfTrades
# 0        1.562197e+12         16411.25       51893.0     1883765
# 1        1.343553e+12         16411.25       61551.0     1614681
# 2        1.261166e+12         16411.25       44717.0     1520394
# 3        1.225334e+12         16411.25      119218.0     1440048
# 4        1.063863e+12         16411.25       64848.0     1324460
# ...               ...              ...           ...         ...
# 1753     0.000000e+00         16411.25           1.0           0
# 1754     0.000000e+00         16411.25           0.0           0
# 1755     0.000000e+00         16411.25           0.0           0
# 1756     0.000000e+00         16411.25           1.0           0
# 1757     0.000000e+00         16411.25           0.0           0
#
# [1758 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['underlying', 'identifier', 'instrumentType', 'instrument', 'contract',
#        'expiryDate', 'optionType', 'strikePrice', 'lastPrice', 'change',
#        'pChange', 'volume', 'totalTurnover', 'value', 'premiumTurnOver',
#        'underlyingValue', 'openInterest', 'noOfTrades'],
#       dtype='object')

# %%
df.dtypes
# Out:
# underlying          object
# identifier          object
# instrumentType      object
# instrument          object
# contract            object
# expiryDate          object
# optionType          object
# strikePrice          int64
# lastPrice          float64
# change             float64
# pChange            float64
# volume               int64
# totalTurnover      float64
# value              float64
# premiumTurnOver    float64
# underlyingValue    float64
# openInterest       float64
# noOfTrades           int64
# dtype: object
